# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### import panda & seaborn libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
iris=pd.read_csv(r"E:\Data Science\senapati\day22\New folder\Iris.csv")

# %%
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
a=iris.drop('Id', axis=1)

# %%
a
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris.drop("Id", axis=1, inplace=True)

# %%
iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# #### now we convert species that is object to the category type

# %%
iris['Species']=iris['Species'].astype('category')

# %%
iris.info()
# now Species converted to category
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    category
# dtypes: category(1), float64(4)
# memory usage: 5.1 KB

# %%
iris.Species.cat.categories
# Out:
# Index(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype='object')

# %%
for sp in iris.Species.cat.categories:
    print(sp)
# Out:
# Iris-setosa
# Iris-versicolor
# Iris-virginica

# %%
iris['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
sns.countplot(data=iris, x='Species')
plt.show()

# %%
sns.countplot('Species',data=iris)
plt.show()
# same as  above code but this is invalid in my jupyter notbook
# bcz this show mi syntax error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 sns.countplot('Species',data=iris)
#       2 plt.show()
#
# TypeError: countplot() got multiple values for argument 'data'

# %%
sns.histplot(data=iris, x='Species')
plt.show
# histogram
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
fig=sns.jointplot(data=iris, x='SepalLengthCm', y='SepalWidthCm')

# %%
sns.jointplot(data=iris, x='SepalLengthCm', y='SepalWidthCm', kind='reg')
# with regreesion line

# %%
sns.jointplot(data=iris, x='SepalLengthCm', y='SepalWidthCm', kind='scatter')

# %%
fig=sns.jointplot(data=iris, x='SepalLengthCm', y='SepalWidthCm', kind='hex')
# jointplot by hexagon

# %%
fig=sns.jointplot(data=iris, x='SepalLengthCm', y='SepalWidthCm', kind='hist')

# %%
fig=sns.jointplot(data=iris, x='SepalLengthCm', y='SepalWidthCm', kind='kde')

# %%
fig=sns.jointplot(data=iris, x='SepalLengthCm', y='SepalWidthCm', kind='resid')

# %% [markdown]
# ### FacetGrid

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

sns.FacetGrid(iris,hue='Species',height=5)\
.map(plt.scatter,'SepalLengthCm','SepalWidthCm')\
.add_legend()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

sns.FacetGrid(iris,hue='Species',height=10)\
.map(plt.scatter,'SepalLengthCm','SepalWidthCm')\
.add_legend()
# only height is changed

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

sns.FacetGrid(iris,hue='Species',height=10)\
.map(plt.scatter,'SepalLengthCm','SepalWidthCm')\
.add_legend()

# %%
iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
for sp in iris.Species.cat.categories:
    print(sp)
# Out:
# Iris-setosa
# Iris-versicolor
# Iris-virginica

# %%
iris.Species.cat.categories
# Out:
# Index(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype='object')

# %%
iris['Species'].unique()
# Out:
# ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']
# Categories (3, object): ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']

# %%
iris[iris['Species']=='Iris-setosa']
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0             5.1           3.5            1.4           0.2  Iris-setosa
# 1             4.9           3.0            1.4           0.2  Iris-setosa
# 2             4.7           3.2            1.3           0.2  Iris-setosa
# 3             4.6           3.1            1.5           0.2  Iris-setosa
# 4             5.0           3.6            1.4           0.2  Iris-setosa
# 5             5.4           3.9            1.7           0.4  Iris-setosa
# 6             4.6           3.4            1.4           0.3  Iris-setosa
# 7             5.0           3.4            1.5           0.2  Iris-setosa
# 8             4.4           2.9            1.4           0.2  Iris-setosa
# 9             4.9           3.1            1.5           0.1  Iris-setosa
# 10            5.4           3.7            1.5           0.2  Iris-setosa
# 11            4.8           3.4            1.6           0.2  Iris-setosa
# ...

# %%
fig=plt.gcf()    
# fig is a only a variable 
# & plt.gcf()---> get current figure (gcf)
fig.set_size_inches(10,7)
fig=sns.boxplot(data=iris, x='Species', y='PetalLengthCm', order=['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], linewidth=3, orient='v', dodge=False )
# orient='v'--> vertical orientation

# %%
fig=plt.gcf()    
# fig is a only a variable 
# & plt.gcf()---> get current figure (gcf)
fig.set_size_inches(10,7)
fig=sns.boxplot(data=iris, x='Species', y='PetalLengthCm', order=['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], linewidth=3, orient='v', dodge=True)

# %%
fig=plt.gcf()    
# fig is a only a variable 
# & plt.gcf()---> get current figure (gcf)
fig.set_size_inches(10,7)
fig=sns.boxplot(data=iris, x='Species', y='PetalLengthCm', order=['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], linewidth=3, orient='h', dodge=False )
# orient='v'--> vertical orientation
# orient='h'    # h--> horizontal
# but h reqired x horizontal prameter hence it shows error please noted
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 5
#       2 # fig is a only a variable
#       3 # & plt.gcf()---> get current figure (gcf)
#       4 fig.set_size_inches(10,7)
# ----> 5 fig=sns.boxplot(data=iris, x='Species', y='PetalLengthCm', order=['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], linewidth=3, orient='h', dodge=False )
#
# File ~\anaconda3\lib\site-packages\seaborn\categorical.py:2231, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2224 def boxplot(
#    2225     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    2226     orient=None, color=None, palette=None, saturation=.75, width=.8,
#    2227     dodge=True, fliersize=5, linewidth=None, whis=1.5, ax=None,
#    2228     **kwargs
#    2229 ):
# ...

# %%
fig=plt.gcf()    
# fig is a only a variable 
# & plt.gcf()---> get current figure (gcf)
fig.set_size_inches(10,7)
fig=sns.boxplot(data=iris, x='Species', y='PetalLengthCm', order=['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], linewidth=6, orient='v', dodge=False )
# here we change linewidth & changes are you noticed

# %%
iris.boxplot(by='Species', figsize=(20,16))
# this means that separate box plots will be created for each unique value in the 'Species' column
# Out:
# array([[<Axes: title={'center': 'PetalLengthCm'}, xlabel='[Species]'>,
#         <Axes: title={'center': 'PetalWidthCm'}, xlabel='[Species]'>],
#        [<Axes: title={'center': 'SepalLengthCm'}, xlabel='[Species]'>,
#         <Axes: title={'center': 'SepalWidthCm'}, xlabel='[Species]'>]],
#       dtype=object)

# %%
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.stripplot(data=iris,x='Species',y='SepalLengthCm',jitter=True,edgecolor='gray',size=8,palette='winter',orient='v')

# %%
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.boxplot(data=iris, x='Species', y='SepalLengthCm')
fig=sns.stripplot(data=iris, x='Species', y='SepalLengthCm',jitter=True, color='yellow' ,edgecolor='gray')
# here we apply color

# %%
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.boxplot(data=iris, x='Species', y='SepalLengthCm')
fig=sns.stripplot(data=iris, x='Species', y='SepalLengthCm',jitter=False, edgecolor='gray')
# here we doesn't apply color
# here we apply jitter=False, then all scatter point (data point) are in s single line

# %%
ax=sns.boxplot(data=iris, x='Species', y='PetalLengthCm')
ax=sns.stripplot(data=iris, x='Species', y='PetalLengthCm', jitter=True, edgecolor='gray')

boxone=ax.artists[2]     # boxtwo is only a variable
boxone.set_facecolor('yellow')
boxone.set_edgecolor('black')
boxtwo=ax.artists[1]
boxtwo.set_facecolor('orange')
boxtwo.set_edgecolor('black')
boxthree=ax.artists[0]
boxthree.set_facecolor('blue')
boxthree.set_edgecolor('black')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[44], line 4
#       1 ax=sns.boxplot(data=iris, x='Species', y='PetalLengthCm')
#       2 ax=sns.stripplot(data=iris, x='Species', y='PetalLengthCm', jitter=True, edgecolor='gray')
# ----> 4 boxone=ax.artists[2]     # boxtwo is only a variable
#       5 boxone.set_facecolor('yellow')
#       6 boxone.set_edgecolor('black')
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py:1457, in _AxesBase.ArtistList.__getitem__(self, key)
#    1456 def __getitem__(self, key):
# -> 1457     return [artist
#    1458             for artist in self._axes._children
#    1459             if self._type_check(artist)][key]
#
# IndexError: list index out of range

# %%
ax= sns.boxplot(x="Species", y="PetalLengthCm", data=iris)
ax= sns.stripplot(x="Species", y="PetalLengthCm", data=iris, jitter=True, edgecolor="gray")

boxtwo = ax.artists[0]
boxtwo.set_facecolor('yellow')
boxtwo.set_edgecolor('black')
boxthree=ax.artists[1]
boxthree.set_facecolor('red')
boxthree.set_edgecolor('black')
boxthree=ax.artists[2]
boxthree.set_facecolor('green')
boxthree.set_edgecolor('black')

plt.show()

# %%
# !pip install seaborn[stats]

# %%
ax= sns.boxplot(x="Species", y="PetalLengthCm", data=iris)
ax= sns.stripplot(x="Species", y="PetalLengthCm", data=iris, jitter=True, edgecolor="gray")

boxtwo = ax.artists[2]
boxtwo.set_facecolor('yellow')
boxtwo.set_edgecolor('black')
boxthree=ax.artists[1]
boxthree.set_facecolor('red')
boxthree.set_edgecolor('black')
boxthree=ax.artists[0]
boxthree.set_facecolor('green')
boxthree.set_edgecolor('black')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[46], line 4
#       1 ax= sns.boxplot(x="Species", y="PetalLengthCm", data=iris)
#       2 ax= sns.stripplot(x="Species", y="PetalLengthCm", data=iris, jitter=True, edgecolor="gray")
# ----> 4 boxtwo = ax.artists[2]
#       5 boxtwo.set_facecolor('yellow')
#       6 boxtwo.set_edgecolor('black')
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py:1457, in _AxesBase.ArtistList.__getitem__(self, key)
#    1456 def __getitem__(self, key):
# -> 1457     return [artist
#    1458             for artist in self._axes._children
#    1459             if self._type_check(artist)][key]
#
# IndexError: list index out of range

# %%
import seaborn as sns
import matplotlib.pyplot as plt

ax = sns.boxplot(x="Species", y="PetalLengthCm", data=iris)
stripplot = sns.stripplot(x="Species", y="PetalLengthCm", data=iris, jitter=True, edgecolor="gray")

# Set facecolor for the scatter dots based on Species category
colors = ['red', 'yellow', 'blue']  # Customize colors as needed
for i, pc in enumerate(stripplot.collections):
    pc.set_facecolor(colors[i])

plt.show()

# %%
ax = sns.boxplot(x="Species", y="PetalLengthCm", data=iris)
ax = sns.stripplot(x="Species", y="PetalLengthCm", data=iris, jitter=True, edgecolor="gray")

# Check the length of ax.artists before accessing an index
if len(ax.artists) >= 3:
    boxtwo = ax.artists[2]
    boxtwo.set_facecolor('yellow')
    boxtwo.set_edgecolor('black')
    boxthree=ax.artists[1]
    boxthree.set_facecolor('red')
    boxthree.set_edgecolor('black')
    boxthree=ax.artists[0]
    boxthree.set_facecolor('green')
    boxthree.set_edgecolor('black')
else:
    print("Not enough artists in the list.")
    
    
plt.show()

# %%
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.violinplot(data=iris, x='Species',y='SepalLengthCm')

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.violinplot(data=iris, x='Species',y='PetalLengthCm')
plt.subplot(2,2,2)
sns.violinplot(data=iris, x='Species',y='PetalWidthCm')
plt.subplot(2,2,3)
sns.violinplot(data=iris, x='Species',y='SepalLengthCm')
plt.subplot(2,2,4)
sns.violinplot(data=iris, x='Species',y='SepalWidthCm')
# Out:
# <Axes: xlabel='Species', ylabel='SepalWidthCm'>

# %%
sns.pairplot(data=iris,kind='scatter')

# %%
sns.pairplot(data=iris,kind='kde')

# %%
sns.pairplot(data=iris,kind='reg')

# %%
sns.pairplot(data=iris,kind='auto')

# %%
sns.pairplot(data=iris,diag_kind='auto')

# %%
iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.pairplot(iris,hue='Species');

# %%
sns.pairplot(iris,hue_order='Species');

# %%
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.heatmap(iris.corr(),annot=True,cmap='cubehelix',linewidths=1,\
                linecolor='k',square=True,mask=False, vmin=-1, vmax=1,\
                cbar_kws={"orientation": "vertical"},cbar=True)

# %%
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.heatmap(iris.corr(),annot=True,cmap='coolwarm',linewidths=5,\
                linecolor='k',square=False,mask=False, vmin=-1, vmax=1,\
                cbar_kws={"orientation": "horizontal"},cbar=True)

# here we change cmap=coolwarm
# linewidth is also be changed
# cbar_kws orientation also are changed

# %%
iris.hist(edgecolor='black', linewidth=2)
fig=plt.gcf()
fig.set_size_inches(12,6)

# %%
fig=plt.gcf()
iris.hist(edgecolor='black', linewidth=2)

fig.set_size_inches(12,6)

# %%
sns.set(style="darkgrid")
fig=plt.gcf()
fig.set_size_inches(10,7)
fig = sns.swarmplot(x="Species", y="PetalLengthCm", data=iris)

# %%
sns.set(style="whitegrid")
fig=plt.gcf()
fig.set_size_inches(10,7)
ax = sns.violinplot(x="Species", y="PetalLengthCm", data=iris, inner=None)
ax = sns.swarmplot(x="Species", y="PetalLengthCm", data=iris,color="white", edgecolor="black")
# here we apply inner=None
# hence we remove the all internal representation of violin plot

# %%
sns.set(style="whitegrid")
fig=plt.gcf()
fig.set_size_inches(10,7)
ax = sns.violinplot(x="Species", y="PetalLengthCm", data=iris)
ax = sns.swarmplot(x="Species", y="PetalLengthCm", data=iris,color="white", edgecolor="black")
# here we remove the inner=None
# bcz of this now it shows all the inner part of violin plot

# %%
fig=sns.lmplot(x="PetalLengthCm", y="PetalWidthCm",data=iris)

# %%
fig=sns.lmplot(x="PetalLengthCm", y="PetalWidthCm",data=iris, fit_reg=False)

# %%
sns.FacetGrid(iris, hue="Species", height=6) \
   .map(sns.kdeplot, "PetalLengthCm") \
   .add_legend()
plt.ioff()

# %%
sns.FacetGrid(iris, hue="Species", height=6) \
   .map(sns.kdeplot, "PetalLengthCm") \
   .add_legend()
plt.show()

# %%
sns.catplot(data=iris, x='Species',y='SepalLengthCm')
plt.ioff()
plt.show()

# %%
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.boxenplot(data=iris, x='Species',y='SepalLengthCm')
plt.show()

# %%
sub = iris[iris['Species'] == 'Iris-setosa']
sns.kdeplot(data=sub['SepalLengthCm'], shade=True, label='Sepal Length (cm)')
sns.kdeplot(data=sub['SepalWidthCm'], shade=True, label='Sepal Width (cm)')
plt.title('Iris-setosa')
plt.xlabel('Measurements')
plt.ylabel('Density')
plt.legend()
plt.show()

# %%
sns.set_style('darkgrid')
f,axes=plt.subplots(2,2,figsize=(15,15))

k1=sns.boxplot(data=iris, x="Species", y="PetalLengthCm",ax=axes[0,0])
k2=sns.violinplot(data=iris, x='Species',y='PetalLengthCm',ax=axes[0,1])
k3=sns.stripplot(data=iris, x='Species',y='SepalLengthCm',jitter=True,edgecolor='gray',size=8,palette='winter',orient='v',ax=axes[1,0])
#axes[1,1].hist(iris.hist,bin=10)
axes[1,1].hist(iris.PetalLengthCm,bins=100)
#k2.set(xlim=(-1,0.8))
plt.show()

# %%
sns.set_style('darkgrid')
f,axes=plt.subplots(2,2,figsize=(15,15))

k1=sns.boxplot(data=iris, x="Species", y="PetalLengthCm",ax=axes[0,0])
k2=sns.violinplot(data=iris, x='Species',y='PetalLengthCm',ax=axes[0,1])
k3=sns.stripplot(data=iris, x='Species',y='SepalLengthCm',jitter=True,edgecolor='gray',size=8,palette='winter',orient='v',ax=axes[1,0])
#axes[1,1].hist(iris.hist,bin=10)
axes[1,1].hist(iris.PetalLengthCm,bins=10)
#k2.set(xlim=(-1,0.8))
plt.show()

# %%
sns.set_style('darkgrid')
f,axes=plt.subplots(2,2,figsize=(15,15))

k1=sns.boxplot(data=iris, x="Species", y="PetalLengthCm",ax=axes[0,0])
k2=sns.violinplot(data=iris, x='Species',y='PetalLengthCm',ax=axes[0,1])
k3=sns.stripplot(data=iris, x='Species',y='SepalLengthCm',jitter=True,edgecolor='gray',size=8,palette='winter',orient='v',ax=axes[1,0])
#axes[1,1].hist(iris.hist,bin=10)
k4=sns.histplot(data=iris, x='PetalLengthCm', hue='Species', multiple='stack', bins=10, ax=axes[1, 1])
#k2.set(xlim=(-1,0.8))
plt.show()

# %%
iris['Species']=iris['Species'].astype('category')

# %%
iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris['Species']=iris['Species'].astype('category')
list1=list()
mylabel=list()
for gen in iris.Species.cat.categories:
    list1.append(iris[iris.Species==gen].SepalLengthCm)
    mylabel.append(gen)
    
h=plt.hist(list1, bins=30, stacked=True, rwidth=1, label=mylabels)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[77], line 8
#       5     list1.append(iris[iris.Species==gen].SepalLengthCm)
#       6     mylabel.append(gen)
# ----> 8 h=plt.hist(list1, bins=30, stacked=True, rwidth=1, label=mylabels)
#       9 plt.legend()
#      10 plt.show()
#
# NameError: name 'mylabels' is not defined

# %%
iris.plot.area(y=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm'],alpha=0.4,figsize=(12, 6));
plt.show()

# %%
sns.distplot(iris['SepalLengthCm'],kde=True,bins=20);
plt.show()
